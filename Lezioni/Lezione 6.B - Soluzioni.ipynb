# %% [markdown]
# <a id='start'></a>
# # Serie storiche
#
# In questo notebook vengono presentati degli esercizi sulle serie storiche (_time series_).
#
# Provate a svolgere il seguente esercizio:<br>
# 1) [Analisi di una time series](#section1)<br>
# 2) [Scomposizione nelle componenti principali](#section2)<br>
# 3) [Eliminazione di trend e stagionalità](#section3)<br>
# 4) [Predizione sulla serie originale](#section4)<br>

# %% [markdown]
# <a id='section1'></a>
# ## Analisi di una time series

# %% [markdown]
# Analizziamo i dati dei passeggeri dei voli di linea negli Stati Uniti:

# %%
import pandas as pd

df = pd.read_csv('data/AirPassengers.csv', parse_dates=['date'], index_col='date')
df
# Out:
#             value
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# 1950-08-01    170
# 1950-09-01    158
# 1950-10-01    133
# 1950-11-01    114
# 1950-12-01    140
# 1951-01-01    145
# 1951-02-01    150
# 1951-03-01    178
# 1951-04-01    163
# 1951-05-01    172
# 1951-06-01    178
# 1951-07-01    199
# 1951-08-01    199
# 1951-09-01    184
# 1951-10-01    162
# 1951-11-01    146
# 1951-12-01    166
# 1952-01-01    171
# 1952-02-01    180
# 1952-03-01    193
# 1952-04-01    181
# 1952-05-01    183
# 1952-06-01    218
# 1952-07-01    230
# 1952-08-01    242
# 1952-09-01    209
# 1952-10-01    191
# 1952-11-01    172
# 1952-12-01    194
# 1953-01-01    196
# 1953-02-01    196
# 1953-03-01    236
# 1953-04-01    235
# 1953-05-01    229
# 1953-06-01    243
# 1953-07-01    264
# 1953-08-01    272
# 1953-09-01    237
# 1953-10-01    211
# 1953-11-01    180
# 1953-12-01    201
# 1954-01-01    204
# 1954-02-01    188
# 1954-03-01    235
# 1954-04-01    227
# 1954-05-01    234
# 1954-06-01    264
# 1954-07-01    302
# 1954-08-01    293
# 1954-09-01    259
# 1954-10-01    229
# 1954-11-01    203
# 1954-12-01    229
# 1955-01-01    242
# 1955-02-01    233
# 1955-03-01    267
# 1955-04-01    269
# 1955-05-01    270
# 1955-06-01    315
# 1955-07-01    364
# 1955-08-01    347
# 1955-09-01    312
# 1955-10-01    274
# 1955-11-01    237
# 1955-12-01    278
# 1956-01-01    284
# 1956-02-01    277
# 1956-03-01    317
# 1956-04-01    313
# 1956-05-01    318
# 1956-06-01    374
# 1956-07-01    413
# 1956-08-01    405
# 1956-09-01    355
# 1956-10-01    306
# 1956-11-01    271
# 1956-12-01    306
# 1957-01-01    315
# 1957-02-01    301
# 1957-03-01    356
# 1957-04-01    348
# 1957-05-01    355
# 1957-06-01    422
# 1957-07-01    465
# 1957-08-01    467
# 1957-09-01    404
# 1957-10-01    347
# 1957-11-01    305
# 1957-12-01    336
# 1958-01-01    340
# 1958-02-01    318
# 1958-03-01    362
# 1958-04-01    348
# 1958-05-01    363
# 1958-06-01    435
# 1958-07-01    491
# 1958-08-01    505
# 1958-09-01    404
# 1958-10-01    359
# 1958-11-01    310
# 1958-12-01    337
# 1959-01-01    360
# 1959-02-01    342
# 1959-03-01    406
# 1959-04-01    396
# 1959-05-01    420
# 1959-06-01    472
# 1959-07-01    548
# 1959-08-01    559
# 1959-09-01    463
# 1959-10-01    407
# 1959-11-01    362
# 1959-12-01    405
# 1960-01-01    417
# 1960-02-01    391
# 1960-03-01    419
# 1960-04-01    461
# 1960-05-01    472
# 1960-06-01    535
# 1960-07-01    622
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432

# %% [markdown]
# Effettuiamo la visualizzazione dei dati con un grafico a linee (sia normale che con two sided view):

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,5))
plt.plot(df.index, df.value)
plt.show()

# %%
import numpy as np

plt.figure(figsize=(16,10))
plt.fill_between(df.index, y1=df.value, y2=-df.value, alpha=0.5, linewidth=2, color='blue')
plt.hlines(y=0, xmin=np.min(df.index), xmax=np.max(df.index), linewidth=.5)
plt.show()

# %% [markdown]
# Analizziamo l'autocorrelazione di questa serie:

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(1, 2, figsize=(20,6))
plot_acf(df.value.tolist(), lags=25, ax=axes[0])
plot_pacf(df.value.tolist(), lags=25, ax=axes[1])
plt.show()

# %% [markdown]
# I dati presentati in questa serie mostrano una certa autocorrelazione ed è possibile vedere che i dati hanno una stagionalità circa annuale (come era facile prevedere).
#
# Proseguiamo quindi con un'analisi di stazionarietà:

# %%
from statsmodels.tsa.stattools import adfuller

X = df.values
result = adfuller(X)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')

for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579

# %% [markdown]
# Dal valore di questa statistica sembra che la serie non sia stazionaria ma abbia un trend o una stagionalità (in realtà possiamo immaginare le abbia entrambe). La serie è molto più probabilmente stazionaria quanto più il valore del Augmented Dickey-Fuller test (ADF) è negativo.

# %% [markdown]
# <a id='section2'></a>
# ## Scomposizione nelle componenti principali

# %% [markdown]
# Eseguiamo le tecniche viste per realizzare una scomposizione nelle componenti principali dei dati di questa serie storica:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# Multiplicative Decomposition 
result_add = seasonal_decompose(df['value'], model='additive', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (10, 12)})
result_add.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# Multiplicative Decomposition 
result_mul = seasonal_decompose(df['value'], model='multiplicative', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (10, 12)})
result_mul.plot()
plt.show()

# %% [markdown]
# <a id='section3'></a>
# ## Eliminazione di trend e stagionalità

# %% [markdown]
# Eliminiamo il trend:

# %%
from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose

result_mul = seasonal_decompose(df['value'], model='multiplicative', extrapolate_trend='freq')
detrended = df.value.values / result_mul.trend

plt.rcParams.update({'figure.figsize': (10, 5)})
plt.plot(df.index, detrended)
plt.show()

# %% [markdown]
# Eliminiamo la stagionalità:

# %%
from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose

result_mul = seasonal_decompose(df['value'], model='multiplicative', extrapolate_trend='freq')
deseasonalized = df.value.values / result_mul.seasonal

plt.rcParams.update({'figure.figsize': (10, 5)})
plt.plot(df.index, deseasonalized)
plt.show()

# %% [markdown]
# Eliminiamo sia trand che stagionalità:

# %%
from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose

result_mul = seasonal_decompose(df['value'], model='multiplicative', extrapolate_trend='freq')
deseasoned = df.value.values / result_mul.seasonal
deseasoned_detrended = deseasoned / result_mul.trend

plt.rcParams.update({'figure.figsize': (10, 5)})
plt.plot(df.index, deseasoned_detrended)
plt.show()

# %% [markdown]
# Proviamo a fare un'analisi di stazionarietà sulla serie così ottenuta:

# %%
new_df = df.copy()
new_df['value'] = deseasoned_detrended

from statsmodels.tsa.stattools import adfuller

result = adfuller(new_df.values)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')

for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.590191
# p-value: 0.000000
# Critical Values:
# 	1%: -3.479
# 	5%: -2.883
# 	10%: -2.578

# %% [markdown]
# I risultati di questa statistica ci dicono che la sere ottenuta è stazionaria con livello di significatività inferiore all'1%.

# %% [markdown]
# <a id='section4'></a>
# ## Predizione della serie originale

# %% [markdown]
# Proviamo a provedere i prossimi 3 anni (36 mesi) dei dati di questa serie:

# %%
import pmdarima as pm

smodel = pm.auto_arima(df,
                       start_p=1, start_q=1,
                       test='adf',
                       max_p=3, max_q=3, m=12,
                       start_P=0, seasonal=True,
                       d=None, D=1, trace=True,
                       error_action='ignore',  
                       suppress_warnings=True, 
                       stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=1024.824, BIC=1039.200, Time=0.404 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=1033.479, BIC=1039.229, Time=0.013 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=1022.316, BIC=1033.817, Time=0.211 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=1022.904, BIC=1034.405, Time=0.272 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=1031.508, BIC=1034.383, Time=0.013 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=1022.343, BIC=1030.968, Time=0.080 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=1021.137, BIC=1035.513, Time=0.726 seconds
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=1017.166, BIC=1034.417, Time=2.219 seconds
# Near non-invertible roots for order (1, 1, 0)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=1022.410, BIC=1036.786, Time=0.435 seconds
# Fit ARIMA(0,1,0)x(2,1,0,12) [intercept=True]; AIC=1034.067, BIC=1045.568, Time=0.485 seconds
# Fit ARIMA(2,1,0)x(2,1,0,12) [intercept=True]; AIC=1023.007, BIC=1040.258, Time=0.896 seconds
# Fit ARIMA(1,1,1)x(2,1,0,12) [intercept=True]; AIC=1022.905, BIC=1040.156, Time=0.837 seconds
# Fit ARIMA(0,1,1)x(2,1,0,12) [intercept=True]; AIC=1021.017, BIC=1035.393, Time=0.486 seconds
# Fit ARIMA(0,1,1)x(1,1,0,12) [intercept=True]; AIC=1022.314, BIC=1033.815, Time=0.156 seconds
# Fit ARIMA(0,1,1)x(2,1,1,12) [intercept=True]; AIC=1015.843, BIC=1033.094, Time=2.190 seconds
# Near non-invertible roots for order (0, 1, 1)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(0,1,1)x(1,1,1,12) [intercept=True]; AIC=1022.207, BIC=1036.583, Time=0.593 seconds
# Fit ARIMA(0,1,2)x(2,1,0,12) [intercept=True]; AIC=1022.996, BIC=1040.247, Time=0.813 seconds
# Fit ARIMA(1,1,2)x(2,1,0,12) [intercept=True]; AIC=1024.668, BIC=1044.795, Time=1.535 seconds
# Total fit time: 12.388 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  144
# Model:             SARIMAX(0, 1, 1)x(2, 1, 1, 12)   Log Likelihood                -501.921
# Date:                            Fri, 16 Apr 2021   AIC                           1015.843
# Time:                                    13:23:03   BIC                           1033.094
# Sample:                                         0   HQIC                          1022.853
#                                             - 144
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0004      0.032      0.012      0.991      -0.063       0.064
# ma.L1         -0.4262      0.068     -6.237      0.000      -0.560      -0.292
# ar.S.L12       0.6670      0.161      4.155      0.000       0.352       0.982
# ar.S.L24       0.3313      0.095      3.480      0.001       0.145       0.518
# ma.S.L12      -0.9727      1.159     -0.839      0.401      -3.245       1.299
# sigma2       111.0578    105.731      1.050      0.294     -96.171     318.286
# ===================================================================================
# Ljung-Box (Q):                       53.00   Jarque-Bera (JB):                 7.40
# Prob(Q):                              0.08   Prob(JB):                         0.02
# Heteroskedasticity (H):               2.82   Skew:                             0.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
n_periods = 36
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(df.index[-1], periods=n_periods+1, freq='MS')[1:]

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize=(16, 7))
plt.plot(df)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

data = pd.concat([df, fitted_series.to_frame(name='value')])
data.index.name = 'date'

# Multiplicative Decomposition 
result_add = seasonal_decompose(data['value'], model='multiplicative', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (10, 12)})
result_add.plot()
plt.show()

# %% [markdown]
# [Clicca qui per tornare all'inizio della pagina](#start)<a id='start'></a>
